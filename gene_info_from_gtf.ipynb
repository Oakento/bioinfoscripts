# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %%
file = "gencode.v22.annotation.gtf.gz"

# %%
df = pd.read_csv(
        file, sep="\t", comment="#", compression='gzip', 
        usecols=[0, 1, 2, 3, 4, 8],
        header=None, names=(
            "chromosome_name", "annotation_source", "feature_type",
            "genomic_start_location", "genomic_end_location", 
            # "score", "genomic_strand", "genomic_phase", 
            "additional_info"
            )
    )
df
# Out:
#         chromosome_name annotation_source feature_type  \
# 0                  chr1            HAVANA         gene
# 1                  chr1            HAVANA   transcript
# 2                  chr1            HAVANA         exon
# 3                  chr1            HAVANA         exon
# 4                  chr1            HAVANA         exon
# ...                 ...               ...          ...
# 2563666            chrM           ENSEMBL   transcript
# 2563667            chrM           ENSEMBL         exon
# 2563668            chrM           ENSEMBL         gene
# 2563669            chrM           ENSEMBL   transcript
# 2563670            chrM           ENSEMBL         exon
#
#          genomic_start_location  genomic_end_location  \
# 0                         11869                 14409
# 1                         11869                 14409
# 2                         11869                 12227
# 3                         12613                 12721
# 4                         13221                 14409
# ...                         ...                   ...
# 2563666                   15888                 15953
# 2563667                   15888                 15953
# 2563668                   15956                 16023
# 2563669                   15956                 16023
# 2563670                   15956                 16023
#
#                                            additional_info
# 0        gene_id "ENSG00000223972.5"; gene_type "transc...
# 1        gene_id "ENSG00000223972.5"; transcript_id "EN...
# 2        gene_id "ENSG00000223972.5"; transcript_id "EN...
# 3        gene_id "ENSG00000223972.5"; transcript_id "EN...
# 4        gene_id "ENSG00000223972.5"; transcript_id "EN...
# ...                                                    ...
# 2563666  gene_id "ENSG00000210195.2"; transcript_id "EN...
# 2563667  gene_id "ENSG00000210195.2"; transcript_id "EN...
# 2563668  gene_id "ENSG00000210196.2"; gene_type "Mt_tRN...
# 2563669  gene_id "ENSG00000210196.2"; transcript_id "EN...
# 2563670  gene_id "ENSG00000210196.2"; transcript_id "EN...
#
# [2563671 rows x 6 columns]

# %%
def parseinfo(s):
    
    items = s['additional_info'].replace(" ", "").split(";")
    gene_id = None
    gene_type = None
    gene_name = None
    for i in items:
        if 'gene_id' in i:
            gene_id = i.split('"')[1]
        elif 'gene_type' in i:
            gene_type = i.split('"')[1]
        elif 'gene_name' in i:
            gene_name = i.split('"')[1]
    return gene_id, gene_type, gene_name

df[['ensembl_id', 'gene_type', 'gene_name']] = df[['additional_info']].progress_apply(parseinfo, axis=1, result_type='expand')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 2563671/2563671 [02:13<00:00, 19139.68it/s]

# %%
new_df = df[["chromosome_name", "annotation_source", "feature_type",
            "genomic_start_location", "genomic_end_location", 
            # "score", "genomic_strand", "genomic_phase", 
            "ensembl_id", "gene_type", "gene_name"]]
new_df
# Out:
#         chromosome_name annotation_source feature_type  \
# 0                  chr1            HAVANA         gene
# 1                  chr1            HAVANA   transcript
# 2                  chr1            HAVANA         exon
# 3                  chr1            HAVANA         exon
# 4                  chr1            HAVANA         exon
# ...                 ...               ...          ...
# 2563666            chrM           ENSEMBL   transcript
# 2563667            chrM           ENSEMBL         exon
# 2563668            chrM           ENSEMBL         gene
# 2563669            chrM           ENSEMBL   transcript
# 2563670            chrM           ENSEMBL         exon
#
#          genomic_start_location  genomic_end_location         ensembl_id  \
# 0                         11869                 14409  ENSG00000223972.5
# 1                         11869                 14409  ENSG00000223972.5
# 2                         11869                 12227  ENSG00000223972.5
# 3                         12613                 12721  ENSG00000223972.5
# 4                         13221                 14409  ENSG00000223972.5
# ...                         ...                   ...                ...
# 2563666                   15888                 15953  ENSG00000210195.2
# 2563667                   15888                 15953  ENSG00000210195.2
# 2563668                   15956                 16023  ENSG00000210196.2
# 2563669                   15956                 16023  ENSG00000210196.2
# 2563670                   15956                 16023  ENSG00000210196.2
#
#                                   gene_type gene_name
# 0        transcribed_unprocessed_pseudogene   DDX11L1
# 1        transcribed_unprocessed_pseudogene   DDX11L1
# 2        transcribed_unprocessed_pseudogene   DDX11L1
# 3        transcribed_unprocessed_pseudogene   DDX11L1
# 4        transcribed_unprocessed_pseudogene   DDX11L1
# ...                                     ...       ...
# 2563666                             Mt_tRNA     MT-TT
# 2563667                             Mt_tRNA     MT-TT
# 2563668                             Mt_tRNA     MT-TP
# 2563669                             Mt_tRNA     MT-TP
# 2563670                             Mt_tRNA     MT-TP
#
# [2563671 rows x 8 columns]

# %%
def unioninterval(l):
    
    def get_union(a, b):
        a0, a1 = a
        b0, b1 = b
        if a1 + 1 == b0:
            return [1, a0, b1]
        if a1 < b0:
            return [2, a, b]
        if a0 <= b0:
            return [1, a0, max(a1, b1)]
    
    l.sort(key=lambda x: x[0])
    i, j = 0, len(l) - 1
    while True:
        if i == j:
            break
        rangea, rangeb = l.pop(i), l.pop(i)
        union_i = get_union(rangea, rangeb)
        if union_i[0] == 1:
            l.insert(i, [union_i[1], union_i[2]])
        elif union_i[0] == 2:
            l.insert(i, union_i[1])
            l.insert(i + 1, union_i[2])
            i += 1
        j = len(l) - 1
    return l

def addup(sdf):
    interval = unioninterval(
        sdf[['genomic_start_location', 'genomic_end_location']].values.tolist()
    )
    length = 0
    for x in interval:
        length += x[1] - x[0] + 1        
    return pd.Series([sdf.iloc[0, :]['gene_name'], length])

exon_df = new_df.loc[new_df['feature_type'] == 'exon', ].groupby('ensembl_id').progress_apply(addup)
exon_df.columns = ['symbol', 'length']
exon_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 60483/60483 [00:43<00:00, 1403.04it/s]
#                            symbol  length
# ensembl_id
# ENSG00000000003.13         TSPAN6    4535
# ENSG00000000005.5            TNMD    1610
# ENSG00000000419.11           DPM1    1207
# ENSG00000000457.12          SCYL3    6883
# ENSG00000000460.15       C1orf112    5967
# ...                           ...     ...
# ENSGR0000275287.3     Metazoa_SRP     290
# ENSGR0000276543.3      AJ271736.1      68
# ENSGR0000277120.3         MIR6089      64
# ENSGR0000280767.1   RP13-465B17.5     515
# ENSGR0000281849.1   RP13-465B17.4     484
#
# [60483 rows x 2 columns]

# %%
exon_df.to_csv('gene.v22.simple.csv')
